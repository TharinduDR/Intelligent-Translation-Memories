# %%
import pandas as pd

# %%
infersent_result = pd.read_csv("result/ES-ES/infersent.tsv", sep="\t")
infersent_result[:10]
# Out:
#                                               source  \
# 0   Commission Implementing Regulation (EU) 2019/281
# 1                                of 12 February 2019
# 2  entering a name in the register of protected d...
# 3                           THE EUROPEAN COMMISSION,
# 4  Having regard to the Treaty on the Functioning...
# 5  Having regard to Regulation (EU) No 1151/2012 ...
# 6                                           Whereas:
# 7  Pursuant to Article 50(2)(a) of Regulation (EU...
# 8  As no statement of opposition under Article 51...
# 9                       HAS ADOPTED THIS REGULATION:
#
#                                               target  \
# 0  Durchführungsverordnung (EU) 2019/281 der Komm...
# 1                               vom 12. Februar 2019
# 2  zur Eintragung einer Bezeichnung in das Regist...
# 3                       DIE EUROPÄISCHE KOMMISSION —
# 4  gestützt auf den Vertrag über die Arbeitsweise...
# 5  gestützt auf die Verordnung (EU) Nr. 1151/2012...
# ...

# %%
sbert_result = pd.read_csv("result/ES-ES/sbert.tsv", sep="\t")
sbert_result[:10]
# Out:
#                                               source  \
# 0   Commission Implementing Regulation (EU) 2019/281
# 1                                of 12 February 2019
# 2  entering a name in the register of protected d...
# 3                           THE EUROPEAN COMMISSION,
# 4  Having regard to the Treaty on the Functioning...
# 5  Having regard to Regulation (EU) No 1151/2012 ...
# 6                                           Whereas:
# 7  Pursuant to Article 50(2)(a) of Regulation (EU...
# 8  As no statement of opposition under Article 51...
# 9                       HAS ADOPTED THIS REGULATION:
#
#                                               target  \
# 0  Durchführungsverordnung (EU) 2019/281 der Komm...
# 1                               vom 12. Februar 2019
# 2  zur Eintragung einer Bezeichnung in das Regist...
# 3                       DIE EUROPÄISCHE KOMMISSION —
# 4  gestützt auf den Vertrag über die Arbeitsweise...
# 5  gestützt auf die Verordnung (EU) Nr. 1151/2012...
# ...

# %%
universal_encoder_result = pd.read_csv("result/ES-ES/universal_encoder.tsv", sep="\t")
universal_encoder_result[:10]
# Out:
#                                               source  \
# 0   Commission Implementing Regulation (EU) 2019/281
# 1                                of 12 February 2019
# 2  entering a name in the register of protected d...
# 3                           THE EUROPEAN COMMISSION,
# 4  Having regard to the Treaty on the Functioning...
# 5  Having regard to Regulation (EU) No 1151/2012 ...
# 6                                           Whereas:
# 7  Pursuant to Article 50(2)(a) of Regulation (EU...
# 8  As no statement of opposition under Article 51...
# 9                       HAS ADOPTED THIS REGULATION:
#
#                                               target  \
# 0  Durchführungsverordnung (EU) 2019/281 der Komm...
# 1                               vom 12. Februar 2019
# 2  zur Eintragung einer Bezeichnung in das Regist...
# 3                       DIE EUROPÄISCHE KOMMISSION —
# 4  gestützt auf den Vertrag über die Arbeitsweise...
# 5  gestützt auf die Verordnung (EU) Nr. 1151/2012...
# ...

# %%
infersent_result_sorted = infersent_result.sort_values('bleu_scores')
infersent_result_sorted = infersent_result_sorted.reset_index(drop=True)
infersent_result_sorted['infersent_bleu_scores'] = infersent_result_sorted['bleu_scores']
infersent_result_sorted[:10]
# Out:
#                                               source  \
# 0                     Determination of working hours
# 1                     Bank of China, Beijing, China,
# 2  National supervisory authorities shall draw up...
# 3        Accell Group (Heerenveen, the Netherlands),
# 4   Derby Cycle Holding GmbH (Cloppenburg, Germany),
# 5  Koninklijke Gazelle NV (Dieren, The Netherlands);
# 6  Suzhou Kaihua Electric Appliance Plastic Facto...
# 7  A verification visit took place at the premise...
# 8                                  (Vitoria, Spain),
# 9                      (Amsterdam, the Netherlands),
#
#                                               target  \
# 0                      Bestimmung der Arbeitsstunden
# 1                      Bank of China, Peking, China,
# 2  Die nationalen Aufsichtsbehörden erstellen Lei...
# 3            Accell Group (Heerenveen, Niederlande),
# 4  Derby Cycle Holding GmbH (Cloppenburg, Deutsch...
# 5      Koninklijke Gazelle NV (Dieren, Niederlande);
# ...

# %%
sbert_result_sorted = sbert_result.sort_values('bleu_scores')
sbert_result_sorted = sbert_result_sorted.reset_index(drop=True)
sbert_result_sorted['sbert_bleu_scores'] = sbert_result_sorted['bleu_scores']
sbert_result_sorted[:10]
# Out:
#                                               source  \
# 0        The position of Director of the Secretariat
# 1  Concerning (2): Approval granted Approval exte...
# 2  Where charges are billed on a regional basis, ...
# 3  The dynamic test shall be performed with a Cla...
# 4  vertically up or down; 6° axially to right or ...
# 5                                             V = V1
# 6              Calculation of terminal service units
# 7  The terminal service unit shall be equal to th...
# 8  Number of months of participation in occupatio...
# 9    For participants without prior work experience:
#
#                                               target  \
# 0        Die Position des Direktors des Sekretariats
# 1  milles käsitletakse mehaanilise haakeseadise v...
# 2  Werden die Gebühren auf regionaler Basis in Re...
# 3  Dünaamiline katse tuleb teha koos sobiva tugev...
# 4  Un angle de rotation axial de 6° vers la droit...
# 5                                            Märkus.
# ...

# %%
universal_encoder_result_sorted = universal_encoder_result.sort_values('bleu_scores')
universal_encoder_result_sorted = universal_encoder_result_sorted.reset_index(drop=True)
universal_encoder_result_sorted['universal_encoder_bleu_scores'] = universal_encoder_result_sorted['bleu_scores']
universal_encoder_result_sorted[:10]
# Out:
#                                               source  \
# 0                                      Communication
# 1                                       Phil. Trans.
# 2  Tucker, A. D. (2010): The correct name to be a...
# 3  Gaban-Lima, R., Raposo, M. A. & Höfling, E. (2...
# 4              A Taxonomic and Geographic Reference.
# 5                                                SAW
# 6  The changes to CITES Resolutions Conf. 11.20 a...
# 7  (2014): Description of a new species of giant ...
# 8                                  Tridacna ningaloo
# 9                                        Tridacnidae
#
#                                               target  \
# 0                                      Kommunikation
# 1                                              Phil.
# 2  Whittaker, A. (2010): The correct name to be a...
# 3  Gaban-Lima, R., Raposo, M. A. and Hofling, E.,...
# 4                A TaxonomicandGeographic Reference.
# 5                                             SAW m3
# ...

# %%
ax = infersent_result_sorted.plot.line(y=['infersent_bleu_scores'])
sbert_result_sorted.plot.line(ax=ax, y=['sbert_bleu_scores'])
universal_encoder_result_sorted.plot.line(ax=ax, y=['universal_encoder_bleu_scores'])

# %%
analysis_full_df = infersent_result[['source','target']]
analysis_full_df["infersent_bleu_scores"] = infersent_result['bleu_scores']
analysis_full_df["sbert_bleu_scores"] = sbert_result['bleu_scores']
analysis_full_df["universal_encoder_bleu_scores"] = universal_encoder_result['bleu_scores']
analysis_full_df[:10]
# Out:
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/tharindu/anaconda3/envs/sentence_similarity_3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
different_rows = analysis_full_df.loc[analysis_full_df['infersent_bleu_scores'] != analysis_full_df['sbert_bleu_scores']]
different_rows[:10]
# Out:
#                                                source  \
# 1                                 of 12 February 2019
# 8   As no statement of opposition under Article 51...
# 11  The name ‘The Vale of Clwyd Denbigh Plum’ (PDO...
# 17                Done at Brussels, 12 February 2019.
# 22                        OJ C 303, 29.8.2018, p. 12.
# 27  Article 1 The name ‘The Vale of Clwyd Denbigh ...
# 29       Council Implementing Regulation (EU) 2019/93
# 38  Two natural persons designated in Annex XV to ...
# 46                 Done at Brussels, 21 January 2019.
# 51  In Regulation (EU) 2017/1509, Annex XV, Part (...
#
#                                                target  infersent_bleu_scores  \
# 1                                vom 12. Februar 2019               0.129099
# 8   Da bei der Kommission kein Einspruch gemäß Art...               0.689108
# 11  Die Bezeichnung „The Vale of Clwyd Denbigh Plu...               0.133456
# ...

# %%
different_rows.shape
# Out:
# (35274, 5)

# %%
different_rows_sorted_infersent = different_rows.sort_values('infersent_bleu_scores')
different_rows_sorted_infersent = different_rows_sorted_infersent.reset_index(drop=True)
different_rows_sorted_infersent[:10]
# Out:
#                                               source  \
# 0                EFCHP,Heat = EmCHP · FCHP,Heat/Qnet
# 1  The A-weighted maximum sound pressure level sh...
# 2  Internal training is training provided by an i...
# 3  Within 60 days of receipt of the grounds for t...
# 4  Within 30 days of the completion of the proced...
# 5  These documents include the 12th Five Year Pla...
# 6  If the occupancy rate is less than 20 % there ...
# 7  That assessment report or opinion shall be pre...
# 8  This is capable of preventing NCAs from taking...
# 9                           for rear braking system:
#
#                                               target  infersent_bleu_scores  \
# 0          EF(KWK,Wärme) = EmKWK · F(KWK,Wärme)/Qnet                    0.0
# 1  Der höchste A-bewertete Schalldruckpegel ist a...                    0.0
# 2  Eine interne Weiterbildung wird von einem inte...                    0.0
# ...

# %%
different_rows_sorted_sbert = different_rows.sort_values('sbert_bleu_scores')
different_rows_sorted_sbert = different_rows_sorted_sbert.reset_index(drop=True)
different_rows_sorted_sbert[:10]
# Out:
#                                               source  \
# 0                                         N. Bădălău
# 1  A load of 1470 daN shall be applied simultaneo...
# 2  A suitable device for the test is shown in Ann...
# 3  The test shall be carried out in both directio...
# 4  However, where more than 900 mm is provided th...
# 5  The retractor shall be tested once for locking...
# 6  A suitable apparatus for the tests specified i...
# 7  The dust used in the test described in paragra...
# 8  In the case of a safety-belt with tension-redu...
# 9  Dynamic test of belt assembly or of the restra...
#
#                                               target  infersent_bleu_scores  \
# 0                                            Formand               0.316228
# 1  Auf beide Gurtbänder ist gleichzeitig eine Kra...               0.010370
# 2  Ein für die Prüfung geeignetes Gerät ist in An...               0.050647
# ...

# %%
ax = different_rows_sorted_infersent.plot.line(y=['infersent_bleu_scores'])
different_rows_sorted_sbert.plot.line(ax=ax, y=['sbert_bleu_scores'])

# %%
different_rows_2 = analysis_full_df.loc[analysis_full_df['universal_encoder_bleu_scores'] != analysis_full_df['sbert_bleu_scores']]
different_rows_2[:10]
# Out:
#                                                source  \
# 1                                 of 12 February 2019
# 2   entering a name in the register of protected d...
# 11  The name ‘The Vale of Clwyd Denbigh Plum’ (PDO...
# 17                Done at Brussels, 12 February 2019.
# 18                                For the Commission,
# 22                        OJ C 303, 29.8.2018, p. 12.
# 24  The name ‘The Vale of Clwyd Denbigh Plum’ (PDO...
# 27  Article 1 The name ‘The Vale of Clwyd Denbigh ...
# 28  Article 1 The name ‘The Vale of Clwyd Denbigh ...
# 29       Council Implementing Regulation (EU) 2019/93
#
#                                                target  infersent_bleu_scores  \
# 1                                vom 12. Februar 2019               0.129099
# 2   zur Eintragung einer Bezeichnung in das Regist...               0.555069
# 11  Die Bezeichnung „The Vale of Clwyd Denbigh Plu...               0.133456
# ...

# %%
different_rows_2.shape
# Out:
# (33671, 5)

# %%
different_rows_sorted_universal_encoder = different_rows.sort_values('universal_encoder_bleu_scores')
different_rows_sorted_universal_encoder = different_rows_sorted_universal_encoder.reset_index(drop=True)
different_rows_sorted_universal_encoder[:10]
# Out:
#                                               source  \
# 0  Description of the situation, including scope ...
# 1  Such delegated and implementing acts, unless o...
# 2  Consequently, the proposed countervailing duty...
# 3  It is also important to note that there was no...
# 4  Information on impurities shall indicate predi...
# 5  the definition of the substance, set down in a...
# 6  As indicated in recital (334), imports into th...
# 7  European Computer Driving Licence (ECDL certif...
# 8  The injury elimination level was adjusted acco...
# 9  These tests shall, wherever applicable, relate...
#
#                                               target  infersent_bleu_scores  \
# 0  Darlegung der Situation, einschließlich des An...               0.000000
# 1  Beidh feidhm ag gníomhartha tarmligthe agus cu...               0.020672
# 2  Dementsprechend werden folgende Ausgleichszoll...               0.012403
# ...

# %%
different_rows_sorted_sbert = different_rows.sort_values('sbert_bleu_scores')
different_rows_sorted_sbert = different_rows_sorted_sbert.reset_index(drop=True)
different_rows_sorted_sbert[:10]
# Out:
#                                               source  \
# 0                                         N. Bădălău
# 1  A load of 1470 daN shall be applied simultaneo...
# 2  A suitable device for the test is shown in Ann...
# 3  The test shall be carried out in both directio...
# 4  However, where more than 900 mm is provided th...
# 5  The retractor shall be tested once for locking...
# 6  A suitable apparatus for the tests specified i...
# 7  The dust used in the test described in paragra...
# 8  In the case of a safety-belt with tension-redu...
# 9  Dynamic test of belt assembly or of the restra...
#
#                                               target  infersent_bleu_scores  \
# 0                                            Formand               0.316228
# 1  Auf beide Gurtbänder ist gleichzeitig eine Kra...               0.010370
# 2  Ein für die Prüfung geeignetes Gerät ist in An...               0.050647
# ...

# %%
ax = different_rows_sorted_universal_encoder.plot.line(y=['universal_encoder_bleu_scores'])
different_rows_sorted_sbert.plot.line(ax=ax, y=['sbert_bleu_scores'])
